# %%
# Mount Google drive to access dataset
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
#import necessary packages
# Import necessary packages
import matplotlib.pyplot as plt
from skimage import feature # This pacakge is used for LBP feature extraction
from sklearn import svm # This pacakge is used for svm classification
from sklearn import metrics
# %matplotlib inline
import cv2
import seaborn as sns # This pacakge is used for better visualization of data (e.g confusion matrix)
# import the packages required 
  
 
from IPython.display import display, HTML, clear_output
## Import the required packages ##
import math, numpy as np
import sklearn.datasets
import os
import h5py
import glob
import keras.utils as image
import tensorflow as tf

# %load_ext tensorboard
from tensorflow import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.11.0
# 2.11.0

# %%
# Unzip dataset in the right directory
# %cd /content/gdrive/MyDrive/42028/ASSESSMENT_1_A/data/
# !unzip dataset_42028assg1_14081525.zip
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: !/!_25251.jpg
#   inflating: !/exp93298.jpg
#   inflating: !/exp25261.jpg
#   inflating: !/exp105700.jpg
#   inflating: !/exp14937.jpg
#   inflating: !/!_10833.jpg
#   inflating: !/exp22633.jpg
#   inflating: !/exp98491.jpg
#   inflating: !/exp11135.jpg
#   inflating: !/exp11317.jpg
#   inflating: !/!_22930.jpg
#   inflating: !/exp91378.jpg
#   inflating: !/!_22054.jpg
#   inflating: !/exp89660.jpg
#   inflating: !/exp10536.jpg
#   inflating: !/exp13314.jpg
#   inflating: !/exp23217.jpg
#   inflating: !/!_11719.jpg
#   inflating: !/!_107286.jpg
#   inflating: !/exp11560.jpg
#   inflating: !/exp12492.jpg
#   inflating: !/exp24677.jpg
#   inflating: !/exp11808.jpg
#   inflating: !/exp97091.jpg
#   inflating: !/exp95218.jpg
#   inflating: !/!_22341.jpg
#   inflating: !/exp12011.jpg
#   inflating: !/!_14337.jpg
#   inflating: !/exp24607.jpg
#   inflating: !/exp84995.jpg
#   inflating: !/exp12580.jpg
# ...

# %%
# Install and import python_splitter. Divides data into test and training samples.

# %%
pip install python_splitter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import python_splitter

# %%
# %cd /content/gdrive/MyDrive/42028/ASSESSMENT_1_A
# Out:
# /content/gdrive/MyDrive/42028/ASSESSMENT_1_A

# %%
# Divide data set into 70% for training and 30% for testing)
python_splitter.split_from_folder("data", train = 0.7, test = 0.3)
# Out:
# ✅Checking SOURCE directory...
# 0.7 0 0.3
# ✅Checking percentage validation...
# ✅Making required directories...
# ✅Shuffling data...
# ✅Getting ready for copying files...
#
# -------------Successfully splitted !!!---------------
